# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np

# %%
def plot_weights(weights, rows, columns):    
    fig, ax = plt.subplots(rows, columns, figsize=(12,4))
    for i in range(rows):
        for j in range(columns):
            filter_idx = columns*i + j
            
            curr_weights = weights[filter_idx,:,:,:]            
            f_min, f_max = curr_weights.min(), curr_weights.max()
            curr_weights = (curr_weights - f_min) / (f_max - f_min)
            
            concat = np.hstack((curr_weights[0], curr_weights[1]))
    
            ax[i,j].imshow(concat, cmap="gray")
            
            ax[i,j].set_xticks([])
            ax[i,j].set_yticks([])

    fig.tight_layout()

# %% [markdown]
# ## EXP 01: 40 filters; Test accuracy: 0.977589163237

# %%
exp_id = "exp01"
weights = np.load("../tmp/{}_simple_unit_weights.npy".format(exp_id))
print(weights.shape)
plot_weights(weights, 5, 8)
# Out:
# (40, 2, 19, 19)

# %% [markdown]
# ## EXP 02: 28 filters; Test accuracy: 0.976011659808

# %%
exp_id = "exp02"
weights = np.load("../tmp/{}_simple_unit_weights.npy".format(exp_id))
print(weights.shape)
plot_weights(weights, 4, 7)
# Out:
# (28, 2, 19, 19)

# %% [markdown]
# ## EXP 03: 24 filters; Test accuracy: 0.9670781893

# %%
exp_id = "exp03"
weights = np.load("../tmp/{}_simple_unit_weights.npy".format(exp_id))
print(weights.shape)
plot_weights(weights, 4, 6)
# Out:
# (24, 2, 19, 19)

# %% [markdown]
# ## EXP 04: 20 filters; Test accuracy: 0.968827160494

# %%
exp_id = "exp04"
weights = np.load("../tmp/{}_simple_unit_weights.npy".format(exp_id))
print(weights.shape)
plot_weights(weights, 4, 5)
# Out:
# (20, 2, 19, 19)

# %% [markdown]
# ## EXP 05: 16 filters; Test accuracy: 0.962945816187

# %%
exp_id = "exp05"
weights = np.load("../tmp/{}_simple_unit_weights.npy".format(exp_id))
print(weights.shape)
plot_weights(weights, 4, 4)
# Out:
# (16, 2, 19, 19)

# %% [markdown]
# ## EXP 06: 12 filters; Test accuracy: 0.957064471879

# %%
exp_id = "exp06"
weights = np.load("../tmp/{}_simple_unit_weights.npy".format(exp_id))
print(weights.shape)
plot_weights(weights, 3, 4)
# Out:
# (12, 2, 19, 19)

# %% [markdown]
# ## EXP 07: 20 filters; Test accuracy: 0.988563100137, n_latent = 100

# %%
exp_id = "exp07"
weights = np.load("../tmp/{}_simple_unit_weights.npy".format(exp_id))
print(weights.shape)
plot_weights(weights, 4, 5)
# Out:
# (20, 2, 19, 19)

# %% [markdown]
# ## EXP 08: 24 filters; Test accuracy: 0.991066529492, n_latent = 100

# %%
exp_id = "exp08"
weights = np.load("../tmp/{}_simple_unit_weights.npy".format(exp_id))
print(weights.shape)
plot_weights(weights, 4, 6)
# Out:
# (24, 2, 19, 19)

# %% [markdown]
# ## EXP 09: 16 filters; Test accuracy: 0.991443758573, n_latent = 100

# %%
exp_id = "exp09"
weights = np.load("../tmp/{}_simple_unit_weights.npy".format(exp_id))
print(weights.shape)
plot_weights(weights, 4, 4)
# Out:
# (16, 2, 19, 19)

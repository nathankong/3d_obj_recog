# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

import pickle

# %%
def load_results_pkl(fname):
    res = pickle.load(open(fname, 'rb'), encoding="latin1")
    return res

def plot_loss_iter(res, train=True):
    assert train
    plt.figure()
    
    if train:
        plt.plot(res["train"]["iter_losses"])
        plt.title("Train Losses")

    plt.title("Loss")
    plt.xlabel("Iteration")

def plot_acc_iter(res, train=True):
    assert train
    plt.figure()
    
    if train:
        plt.plot(res["train"]["iter_top1_accs"], label="Top 1", color="blue")
        plt.title("Train Accuracy")
        
    plt.xlabel("Iteration")
    plt.legend()

def plot_loss_epoch(res, train=True):
    plt.figure()
    
    if train:
        plt.plot(res["train"]["losses"])
        plt.title("Train Losses")

    plt.title("Loss")
    plt.xlabel("Epoch")

def plot_acc_epoch(res, train=True):
    plt.figure()
    
    if train:
        plt.plot(res["train"]["top1_accs"], label="Top 1", color="blue")
        plt.title("Train Accuracy")
    else:
        plt.plot(res["val"]["top1_accs"], label="Top 1", color="blue")
        plt.title("Validation Accuracy")
        print("Max Top-1 Validation Accuracy {}".format(np.max(res["val"]["top1_accs"])))
        
        print(res["val"]["top1_accs"])

    plt.xlabel("Epoch")
    plt.legend()

# %%
fname = "/mnt/fs5/nclkong/trained_models/norb/test/results.pkl"
res = load_results_pkl(fname)
plot_acc_iter(res)
plot_acc_epoch(res)
plot_acc_epoch(res, train=False)
# Out:
# Max Top-1 Validation Accuracy 0.8743655694201486
# [0.6744513029260727, 0.7628772290972852, 0.7915809326211121, 0.8050068587105624, 0.8006687244433598, 0.8471021949181995, 0.8500514403128656, 0.8392489710625961, 0.856430041250378, 0.8321502059575462, 0.8650377226955116, 0.8501371740804288, 0.8469135803613806, 0.8618827161147925, 0.8546982165390244, 0.8618141288456439, 0.8667866938725748, 0.8705932783164769, 0.8681927299139758, 0.8519890258014611, 0.8743655694201486, 0.861779835374594, 0.8709019202100233, 0.857750342821061, 0.8722050752168821, 0.8649691358678789, 0.8711419752759371, 0.8682098764123903, 0.8728566529983028, 0.8686213991278974]

# %%
fname = "/mnt/fs5/nclkong/trained_models/norb/exp11_nlatent_50/results.pkl"
res = load_results_pkl(fname)
plot_acc_iter(res)
plot_acc_epoch(res)
plot_acc_epoch(res, train=False)
# Out:
# Max Top-1 Validation Accuracy 0.8779320987654321
# [0.7599622771409641, 0.8273662549150987, 0.8308984909037994, 0.8221879284241236, 0.8589677642565859, 0.8463134432689317, 0.8616941013290395, 0.8653806584525664, 0.8428326472987527, 0.8614540467536989, 0.8757716051345009, 0.876217420994009, 0.8716735251973522, 0.8738511658990334, 0.8678840876116184, 0.876594650303876, 0.8779320987654321, 0.8775205761316872, 0.873696844796912, 0.8747942388793568, 0.8757030176527706, 0.8769032923609468, 0.8734567901234568, 0.8755658437195138, 0.8745713305898491, 0.8750171468745207, 0.8715363510842186, 0.8757716048401569, 0.8726851853814145, 0.8745198901625164]

# %%
fname = "/mnt/fs5/nclkong/trained_models/norb/exp12_nlatent_100/results.pkl"
res = load_results_pkl(fname)
plot_acc_iter(res)
plot_acc_epoch(res)
plot_acc_epoch(res, train=False)
# Out:
# Max Top-1 Validation Accuracy 0.8974451304953776
# [0.4692558299857403, 0.5761488340682617, 0.6480967080315118, 0.7139574760435704, 0.6967078190608607, 0.7669238685089865, 0.7578875172121862, 0.7895747600759498, 0.7618998630383704, 0.782527435005774, 0.816889574939822, 0.7917352539358152, 0.843038408795502, 0.8299725653049224, 0.8108882030341851, 0.8359739370306823, 0.8440500686688678, 0.8427812072638785, 0.853515089261352, 0.8362482855185887, 0.8350823045758063, 0.861814128960111, 0.831310013897298, 0.8676097394017035, 0.8719993142924681, 0.8608539096776023, 0.8667524007285737, 0.7989197532990014, 0.872839506303659, 0.8799725653376271, 0.8695644719937538, 0.8629115227645644, 0.8658779150501037, 0.8543895749561744, 0.8672839508135133, 0.8750685872527961, 0.8837962963944109, 0.8625342937653938, 0.8413065844111972, 0.8742283951598431, 0.8818244170586595, 0.851063100202584, 0.8855967080315118, 0.8974451304953776, 0.8781550070058826, 0.8783779151809232, 0.8939471881085462, 0.8928669411622612, 0.8938271605755893, 0.8804698217389352, 0.8806927299139758, 0.8888717422105975, 0.885185185250595, 0.8915637860736402, 0.893621399258717, 0.8921124830658054, 0.8923182442518582, 0.8921467764714455, 0.8929698218206973, 0.8940843622216799, 0.8928497944676173, 0.8883744858092896, 0.8927640605692346, 0.8921296298422113, 0.8925240056995501, 0.8928669412276709, 0.8925925928051743, 0.8918724281961208, 0.8917009604320605, 0.8920953362893993, 0.8928669412276709, 0.8925925928051743, 0.8924554185939261, 0.892472565370332, 0.892472565370332]

# %%
fname = "/mnt/fs5/nclkong/trained_models/norb/exp13_nlatent_100/results.pkl"
res = load_results_pkl(fname)
plot_acc_iter(res)
plot_acc_epoch(res)
plot_acc_epoch(res, train=False)
# Out:
# Max Top-1 Validation Accuracy 0.8890946502384662

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

import pickle

# %%
def load_results_pkl(fname):
    res = pickle.load(open(fname, 'rb'), encoding="latin1")
    return res

def plot_losses(losses):
    plt.figure()
    plt.plot(losses["train"], label="train")
    plt.plot(losses["val"], label="val")
    plt.title("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    print("Best epoch val loss:", np.min(losses["val"]))

def plot_accs(accs):
    plt.figure()
    plt.plot(accs["train"], label="train")
    plt.plot(accs["val"], label="val")
    plt.title("Accuracy")
    plt.xlabel("Epoch")
    plt.legend()
    print("Best epoch val accuracy:", np.max(accs["val"]))

# %% [markdown]
# ## EXP 01: 40 filters

# %%
exp_id = "exp01"
dataset = "norb"
results_fname = "results.pkl"
results_path = "/mnt/fs5/nclkong/trained_models/{}/{}/".format(dataset, exp_id)

res = load_results_pkl(results_path + results_fname)
losses = res["losses"]
accs = res["accs"]

plot_losses(losses)
plot_accs(accs)
# Out:
# Best epoch val loss: 0.291869330557449
# Best epoch val accuracy: 0.9092421124828532

# %% [markdown]
# ## EXP 02: 28 filters

# %%
exp_id = "exp02"
dataset = "norb"
results_fname = "results.pkl"
results_path = "/mnt/fs5/nclkong/trained_models/{}/{}/".format(dataset, exp_id)

res = load_results_pkl(results_path + results_fname)
losses = res["losses"]
accs = res["accs"]

plot_losses(losses)
plot_accs(accs)
# Out:
# Best epoch val loss: 0.305297868536333
# Best epoch val accuracy: 0.9016632373113854

# %% [markdown]
# ## EXP 03: 24 filters

# %%
exp_id = "exp03"
dataset = "norb"
results_fname = "results.pkl"
results_path = "/mnt/fs5/nclkong/trained_models/{}/{}/".format(dataset, exp_id)

res = load_results_pkl(results_path + results_fname)
losses = res["losses"]
accs = res["accs"]

plot_losses(losses)
plot_accs(accs)
# Out:
# Best epoch val loss: 0.30712349884549284
# Best epoch val accuracy: 0.9023319615912209

# %% [markdown]
# ## EXP 04: 20 filters

# %%
exp_id = "exp04"
dataset = "norb"
results_fname = "results.pkl"
results_path = "/mnt/fs5/nclkong/trained_models/{}/{}/".format(dataset, exp_id)

res = load_results_pkl(results_path + results_fname)
losses = res["losses"]
accs = res["accs"]

plot_losses(losses)
plot_accs(accs)
# Out:
# Best epoch val loss: 0.33836514600673984
# Best epoch val accuracy: 0.8915809327846365

# %% [markdown]
# ## EXP 05: 16 filters: python code/train_bnn.py --cuda 6 --exp-id exp05 --num-kernels 16

# %%
exp_id = "exp05"
dataset = "norb"
results_fname = "results.pkl"
results_path = "/mnt/fs5/nclkong/trained_models/{}/{}/".format(dataset, exp_id)

res = load_results_pkl(results_path + results_fname)
losses = res["losses"]
accs = res["accs"]

plot_losses(losses)
plot_accs(accs)
# Out:
# Best epoch val loss: 0.30858860122977627
# Best epoch val accuracy: 0.9015775034293553

# %% [markdown]
# ## EXP 06: 12 filters: python code/train_bnn.py --cuda 6 --exp-id exp06 --num-kernels 12

# %%
exp_id = "exp06"
dataset = "norb"
results_fname = "results.pkl"
results_path = "/mnt/fs5/nclkong/trained_models/{}/{}/".format(dataset, exp_id)

res = load_results_pkl(results_path + results_fname)
losses = res["losses"]
accs = res["accs"]

plot_losses(losses)
plot_accs(accs)
# Out:
# Best epoch val loss: 0.36358626941103994
# Best epoch val accuracy: 0.884139231824417

# %% [markdown]
# ## Exp 07: python code/train_bnn.py --cuda 8 --num-latent 100 --exp-id exp07 --num-kernels 20

# %%
exp_id = "exp07"
dataset = "norb"
results_fname = "results.pkl"
results_path = "/mnt/fs5/nclkong/trained_models/{}/{}/".format(dataset, exp_id)

res = load_results_pkl(results_path + results_fname)
losses = res["losses"]
accs = res["accs"]

plot_losses(losses)
plot_accs(accs)
# Out:
# Best epoch val loss: 0.3040762733448353
# Best epoch val accuracy: 0.908676268861454

# %% [markdown]
# ## Exp 08: python code/train_bnn.py --cuda 8 --num-latent 100 --exp-id exp08 --num-kernels 24

# %%
exp_id = "exp08"
dataset = "norb"
results_fname = "results.pkl"
results_path = "/mnt/fs5/nclkong/trained_models/{}/{}/".format(dataset, exp_id)

res = load_results_pkl(results_path + results_fname)
losses = res["losses"]
accs = res["accs"]

plot_losses(losses)
plot_accs(accs)
# Out:
# Best epoch val loss: 0.3004856060991071
# Best epoch val accuracy: 0.911042524005487

# %% [markdown]
# ## Exp 09: python code/train_bnn.py --cuda 8 --num-latent 100 --exp-id exp08 --num-kernels 16

# %%
exp_id = "exp09"
dataset = "norb"
results_fname = "results.pkl"
results_path = "/mnt/fs5/nclkong/trained_models/{}/{}/".format(dataset, exp_id)

res = load_results_pkl(results_path + results_fname)
losses = res["losses"]
accs = res["accs"]

plot_losses(losses)
plot_accs(accs)
# Out:
# Best epoch val loss: 0.29138448297241587
# Best epoch val accuracy: 0.9083333333333333

# %% [markdown]
# ## python code/train_bnn.py --cuda 1 --num-latent 10 --exp-id exp10 --num-kernels 16

# %%
exp_id = "exp10"
dataset = "norb"
results_fname = "results.pkl"
results_path = "/mnt/fs5/nclkong/trained_models/{}/{}/".format(dataset, exp_id)

res = load_results_pkl(results_path + results_fname)
losses = res["losses"]
accs = res["accs"]

plot_losses(losses)
plot_accs(accs)
# Out:
# Best epoch val loss: 0.4651640044645354
# Best epoch val accuracy: 0.8305555555555556
